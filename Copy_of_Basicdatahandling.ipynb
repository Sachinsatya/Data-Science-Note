# %% [markdown]
# <a href="https://colab.research.google.com/github/Sachinsatya/data_insights-/blob/main/Copy_of_Basicdatahandling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ----- Cleaning and organize the data before cleaning it
# ------ Eliminate Duplicate (Data)
# -----   Find the Replace (Home)
# -----     Sort the data (dta)
# -----

# %%
df = pd.read_csv('/content/Cars Data.csv')

# %%
df
# Out:
#       Make                    Model   Type  Origin DriveTrain      MSRP  \
# 0    Acura                      MDX    SUV    Asia        All  $36,945
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  $26,990
# 3    Acura                   TL 4dr  Sedan    Asia      Front  $33,195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  $43,755
# ..     ...                      ...    ...     ...        ...       ...
# 427  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 428  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 429  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 430  Volvo                      V40  Wagon  Europe      Front  $26,135
# 431  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %%
df.head(5)
# Out:
#     Make           Model   Type Origin DriveTrain      MSRP   Invoice  \
# 0  Acura             MDX    SUV   Asia        All  $36,945   $33,337
# 1  Acura  RSX Type S 2dr  Sedan   Asia      Front  $23,820   $21,761
# 2  Acura         TSX 4dr  Sedan   Asia      Front  $26,990   $24,647
# 3  Acura          TL 4dr  Sedan   Asia      Front  $33,195   $30,299
# 4  Acura      3.5 RL 4dr  Sedan   Asia      Front  $43,755   $39,014
#
#    EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 0         3.5        6.0       265.0      17.0         23.0  4451.0
# 1         2.0        4.0       200.0      24.0         31.0  2778.0
# 2         2.4        4.0       200.0      22.0         29.0  3230.0
# 3         3.2        6.0       270.0      20.0         28.0  3575.0
# 4         3.5        6.0       225.0      18.0         24.0  3880.0
#
#    Wheelbase  Length
# 0      106.0   189.0
# 1      101.0   172.0
# 2      105.0   183.0
# 3      108.0   186.0
# 4      115.0   197.0

# %%
dfc = df

# %%
dfc.isna().sum()
# Out:
# Make           4
# Model          4
# Type           4
# Origin         4
# DriveTrain     4
# MSRP           4
# Invoice        4
# EngineSize     4
# Cylinders      6
# Horsepower     4
# MPG_City       4
# MPG_Highway    4
# Weight         4
# Wheelbase      4
# Length         4
# dtype: int64

# %% [markdown]
# DROP or Median or Mean If categarical value Mode

# %%
dfc.dropna(inplace = True)

# %%
dfc.isna().sum()
# Out:
# Make           0
# Model          0
# Type           0
# Origin         0
# DriveTrain     0
# MSRP           0
# Invoice        0
# EngineSize     0
# Cylinders      0
# Horsepower     0
# MPG_City       0
# MPG_Highway    0
# Weight         0
# Wheelbase      0
# Length         0
# dtype: int64

# %%
dfc.sample(5)
# Out:
#               Make                  Model    Type  Origin DriveTrain  \
# 198         Jaguar        Vanden Plas 4dr   Sedan  Europe       Rear
# 273  Mercedes-Benz  SL500 convertible 2dr  Sports  Europe       Rear
# 203         Jaguar          XKR coupe 2dr  Sports  Europe       Rear
# 69       Chevrolet               Aveo 4dr   Sedan     USA      Front
# 108          Dodge            Neon SE 4dr   Sedan     USA      Front
#
#          MSRP   Invoice  EngineSize  Cylinders  Horsepower  MPG_City  \
# 198  $68,995   $62,846          4.2        8.0       294.0      18.0
# 273  $90,520   $84,325          5.0        8.0       302.0      16.0
# 203  $81,995   $74,676          4.2        8.0       390.0      16.0
# 69   $11,690   $10,965          1.6        4.0       103.0      28.0
# 108  $13,670   $12,849          2.0        4.0       132.0      29.0
#
#      MPG_Highway  Weight  Wheelbase  Length
# 198         28.0  3803.0      119.0   200.0
# 273         23.0  4065.0      101.0   179.0
# ...

# %%
sns.histplot(dfc, bins = 30)

# %%
dfc.describe()
# Out:
#        EngineSize   Cylinders  Horsepower    MPG_City  MPG_Highway  \
# count  426.000000  426.000000  426.000000  426.000000   426.000000
# mean     3.205634    5.807512  215.877934   20.070423    26.854460
# std      1.103520    1.558443   71.991040    5.248616     5.752335
# min      1.400000    3.000000   73.000000   10.000000    12.000000
# 25%      2.400000    4.000000  165.000000   17.000000    24.000000
# 50%      3.000000    6.000000  210.000000   19.000000    26.000000
# 75%      3.900000    6.000000  255.000000   21.750000    29.000000
# max      8.300000   12.000000  500.000000   60.000000    66.000000
#
#             Weight   Wheelbase      Length
# count   426.000000  426.000000  426.000000
# mean   3580.474178  108.164319  186.420188
# std     759.870073    8.330030   14.366611
# min    1850.000000   89.000000  143.000000
# 25%    3111.250000  103.000000  178.000000
# 50%    3476.000000  107.000000  187.000000
# 75%    3979.250000  112.000000  194.000000
# ...

# %%
dfc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 426 entries, 0 to 431
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Make         426 non-null    object
#  1   Model        426 non-null    object
#  2   Type         426 non-null    object
#  3   Origin       426 non-null    object
#  4   DriveTrain   426 non-null    object
#  5   MSRP         426 non-null    object
#  6   Invoice      426 non-null    object
#  7   EngineSize   426 non-null    float64
#  8   Cylinders    426 non-null    float64
#  9   Horsepower   426 non-null    float64
#  10  MPG_City     426 non-null    float64
#  11  MPG_Highway  426 non-null    float64
#  12  Weight       426 non-null    float64
#  13  Wheelbase    426 non-null    float64
#  14  Length       426 non-null    float64
# dtypes: float64(8), object(7)
# memory usage: 53.2+ KB

# %%
dfc.shape
# Out:
# (426, 15)

# %%
dfc.columns
# Out:
# Index(['Make', 'Model', 'Type', 'Origin', 'DriveTrain', 'MSRP', 'Invoice',
#        'EngineSize', 'Cylinders', 'Horsepower', 'MPG_City', 'MPG_Highway',
#        'Weight', 'Wheelbase', 'Length'],
#       dtype='object')

# %%
dfc.tail()
# Out:
#       Make                    Model   Type  Origin DriveTrain      MSRP  \
# 427  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 428  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 429  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 430  Volvo                      V40  Wagon  Europe      Front  $26,135
# 431  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# 427  $38,203          2.4        5.0       197.0      21.0         28.0
# 428  $40,083          2.3        5.0       242.0      20.0         26.0
# 429  $42,573          2.9        6.0       268.0      19.0         26.0
# 430  $24,641          1.9        4.0       170.0      22.0         29.0
# 431  $33,112          2.5        5.0       208.0      20.0         27.0
#
#      Weight  Wheelbase  Length
# 427  3450.0      105.0   186.0
# 428  3450.0      105.0   186.0
# ...

# %%
dfc.dtypes
# Out:
# Make            object
# Model           object
# Type            object
# Origin          object
# DriveTrain      object
# MSRP            object
# Invoice         object
# EngineSize     float64
# Cylinders      float64
# Horsepower     float64
# MPG_City       float64
# MPG_Highway    float64
# Weight         float64
# Wheelbase      float64
# Length         float64
# dtype: object

# %%
dfc.Make.unique()
# Out:
# array(['Acura', 'Audi', 'BMW', 'Buick', 'Cadillac', 'Chevrolet',
#        'Chrysler', 'Dodge', 'Ford', 'GMC', 'Honda', 'Hummer', 'Hyundai',
#        'Infiniti', 'Isuzu', 'Jaguar', 'Jeep', 'Kia', 'Land Rover',
#        'Lexus', 'Lincoln', 'MINI', 'Mazda', 'Mercedes-Benz', 'Mercury',
#        'Mitsubishi', 'Nissan', 'Oldsmobile', 'Pontiac', 'Porsche', 'Saab',
#        'Saturn', 'Scion', 'Subaru', 'Suzuki', 'Toyota', 'Volkswagen',
#        'Volvo'], dtype=object)

# %%
Model = dfc.Model.unique()

# %%
pd.DataFrame(Model)
# Out:
#                            0
# 0                        MDX
# 1             RSX Type S 2dr
# 2                    TSX 4dr
# 3                     TL 4dr
# 4                 3.5 RL 4dr
# ..                       ...
# 418  C70 LPT convertible 2dr
# 419  C70 HPT convertible 2dr
# 420               S80 T6 4dr
# 421                      V40
# 422                     XC70
#
# [423 rows x 1 columns]

# %%
dfc.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 427    False
# 428    False
# 429    False
# 430    False
# 431    False
# Length: 426, dtype: bool

# %%
dfc.duplicated().sum()
# Out:
# 0

# %%
plt.figure(figsize = (20,8))
sns.distplot(dfc.EngineSize, bins = 30)
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
dfc.T
# Out:
#                   0               1         2         3           4    \
# Make            Acura           Acura     Acura     Acura       Acura
# Model             MDX  RSX Type S 2dr   TSX 4dr    TL 4dr  3.5 RL 4dr
# Type              SUV           Sedan     Sedan     Sedan       Sedan
# Origin           Asia            Asia      Asia      Asia        Asia
# DriveTrain        All           Front     Front     Front       Front
# MSRP         $36,945         $23,820   $26,990   $33,195     $43,755
# Invoice      $33,337         $21,761   $24,647   $30,299     $39,014
# EngineSize        3.5             2.0       2.4       3.2         3.5
# Cylinders         6.0             4.0       4.0       6.0         6.0
# Horsepower      265.0           200.0     200.0     270.0       225.0
# MPG_City         17.0            24.0      22.0      20.0        18.0
# MPG_Highway      23.0            31.0      29.0      28.0        24.0
# ...

# %%
dfc.describe().T
# Out:
#              count         mean         std     min      25%     50%      75%  \
# EngineSize   426.0     3.205634    1.103520     1.4     2.40     3.0     3.90
# Cylinders    426.0     5.807512    1.558443     3.0     4.00     6.0     6.00
# Horsepower   426.0   215.877934   71.991040    73.0   165.00   210.0   255.00
# MPG_City     426.0    20.070423    5.248616    10.0    17.00    19.0    21.75
# MPG_Highway  426.0    26.854460    5.752335    12.0    24.00    26.0    29.00
# Weight       426.0  3580.474178  759.870073  1850.0  3111.25  3476.0  3979.25
# Wheelbase    426.0   108.164319    8.330030    89.0   103.00   107.0   112.00
# Length       426.0   186.420188   14.366611   143.0   178.00   187.0   194.00
#
#                 max
# EngineSize      8.3
# Cylinders      12.0
# Horsepower    500.0
# MPG_City       60.0
# MPG_Highway    66.0
# Weight       7190.0
# Wheelbase     144.0
# Length        238.0

# %% [markdown]
# Loc and iloc    Loc used for columns iloc used for rows

# %%
dfc.iloc[ 2 , 10]
# Out:
# 22.0

# %%
dfc.iloc[ :5 , :]
# Out:
#     Make           Model   Type Origin DriveTrain      MSRP   Invoice  \
# 0  Acura             MDX    SUV   Asia        All  $36,945   $33,337
# 1  Acura  RSX Type S 2dr  Sedan   Asia      Front  $23,820   $21,761
# 2  Acura         TSX 4dr  Sedan   Asia      Front  $26,990   $24,647
# 3  Acura          TL 4dr  Sedan   Asia      Front  $33,195   $30,299
# 4  Acura      3.5 RL 4dr  Sedan   Asia      Front  $43,755   $39,014
#
#    EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 0         3.5        6.0       265.0      17.0         23.0  4451.0
# 1         2.0        4.0       200.0      24.0         31.0  2778.0
# 2         2.4        4.0       200.0      22.0         29.0  3230.0
# 3         3.2        6.0       270.0      20.0         28.0  3575.0
# 4         3.5        6.0       225.0      18.0         24.0  3880.0
#
#    Wheelbase  Length
# 0      106.0   189.0
# 1      101.0   172.0
# 2      105.0   183.0
# 3      108.0   186.0
# 4      115.0   197.0

# %%
dfc.iloc[ :5 , :3]
# Out:
#     Make           Model   Type
# 0  Acura             MDX    SUV
# 1  Acura  RSX Type S 2dr  Sedan
# 2  Acura         TSX 4dr  Sedan
# 3  Acura          TL 4dr  Sedan
# 4  Acura      3.5 RL 4dr  Sedan

# %%
dfc.loc[ 5 , 'Make']
# Out:
# 'Acura'

# %%
dfc['Make'].duplicated().sum()
# Out:
# 388

# %%
dfc.duplicated().sum()
# Out:
# 0

# %%
dfc.drop_duplicates(subset = ['Make'], keep = False)
# Out:
#        Make Model Type Origin DriveTrain      MSRP   Invoice  EngineSize  \
# 169  Hummer    H2  SUV    USA        All  $49,995   $45,815          6.0
#
#      Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  Wheelbase  Length
# 169        8.0       316.0      10.0         12.0  6400.0      123.0   190.0

# %%
dfc.drop_duplicates()
# Out:
#       Make                    Model   Type  Origin DriveTrain      MSRP  \
# 0    Acura                      MDX    SUV    Asia        All  $36,945
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  $26,990
# 3    Acura                   TL 4dr  Sedan    Asia      Front  $33,195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  $43,755
# ..     ...                      ...    ...     ...        ...       ...
# 427  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 428  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 429  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 430  Volvo                      V40  Wagon  Europe      Front  $26,135
# 431  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %%
dfc.shape
# Out:
# (426, 15)

# %%
dfc['Make'].value_counts()
# Out:
# Toyota           28
# Chevrolet        27
# Mercedes-Benz    26
# Ford             23
# BMW              20
# Audi             19
# Honda            17
# Nissan           17
# Volkswagen       15
# Chrysler         15
# Dodge            13
# Mitsubishi       13
# Hyundai          12
# Jaguar           12
# Volvo            12
# Subaru           11
# Pontiac          11
# Lexus            11
# Kia              11
# Lincoln           9
# Buick             9
# Mazda             9
# Mercury           9
# Saturn            8
# Cadillac          8
# Suzuki            8
# Infiniti          8
# GMC               8
# Acura             7
# Porsche           7
# Saab              7
# Land Rover        3
# Oldsmobile        3
# Jeep              3
# Scion             2
# Isuzu             2
# MINI              2
# Hummer            1
# Name: Make, dtype: int64
